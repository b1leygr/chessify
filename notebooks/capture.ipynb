# %%
import cv2
cap = cv2.VideoCapture(0)
cap.set(3,1920) #width=1920
cap.set(4,1080) #height=1080
# Out:
# True

# %%
game = input("Enter game name:")
i = -1
while True:
    img_name = input("Enter name for image (or 'q' to quit): ")
    if img_name.lower() == 'q':
        break
    if cap.isOpened():
        _,frame = cap.read()
        _,frame = cap.read()
        if _ and frame is not None:
            cv2.imwrite(f'{game}_{i}.jpg', frame)
            print(f"Image saved as {game}_{i}.jpg")
            i += 1
cap.release() #releasing camera after capturing pictures
# Out:
# Image saved as runau_schmidt72_-1.jpg
# Image saved as runau_schmidt72_0.jpg
# Image saved as runau_schmidt72_1.jpg
# Image saved as runau_schmidt72_2.jpg
# Image saved as runau_schmidt72_3.jpg
# Image saved as runau_schmidt72_4.jpg
# Image saved as runau_schmidt72_5.jpg
# Image saved as runau_schmidt72_6.jpg
# Image saved as runau_schmidt72_7.jpg
# Image saved as runau_schmidt72_8.jpg
# Image saved as runau_schmidt72_9.jpg
# Image saved as runau_schmidt72_10.jpg
# Image saved as runau_schmidt72_11.jpg
# Image saved as runau_schmidt72_12.jpg
# Image saved as runau_schmidt72_13.jpg
# Image saved as runau_schmidt72_14.jpg
# Image saved as runau_schmidt72_15.jpg
# Image saved as runau_schmidt72_16.jpg
# Image saved as runau_schmidt72_17.jpg
# Image saved as runau_schmidt72_18.jpg
# Image saved as runau_schmidt72_19.jpg
# Image saved as runau_schmidt72_20.jpg
# Image saved as runau_schmidt72_21.jpg
# Image saved as runau_schmidt72_22.jpg
# Image saved as runau_schmidt72_23.jpg
# ...

# %%
game = 'turochamp_glennie'
i = -1
while True:
    img_name = input("Enter name for image (or 'q' to quit): ")
    if img_name.lower() == 'q':
        break
    if cap.isOpened():
        _,frame = cap.read()
        _,frame = cap.read()
        if _ and frame is not None:
            cv2.imwrite(f'{game}_{i}.jpg', frame)
            print(f"Image saved as {game}_{i}.jpg")
            i += 1
cap.release() #releasing camera after capturing pictures
# Out:
# Image saved as turochamp_glennie_-1.jpg
# Image saved as turochamp_glennie_0.jpg
# Image saved as turochamp_glennie_1.jpg
# Image saved as turochamp_glennie_2.jpg
# Image saved as turochamp_glennie_3.jpg
# Image saved as turochamp_glennie_4.jpg
# Image saved as turochamp_glennie_5.jpg
# Image saved as turochamp_glennie_6.jpg
# Image saved as turochamp_glennie_7.jpg
# Image saved as turochamp_glennie_8.jpg
# Image saved as turochamp_glennie_9.jpg
# Image saved as turochamp_glennie_10.jpg
# Image saved as turochamp_glennie_11.jpg
# Image saved as turochamp_glennie_12.jpg
# Image saved as turochamp_glennie_13.jpg
# Image saved as turochamp_glennie_14.jpg
# Image saved as turochamp_glennie_15.jpg
# Image saved as turochamp_glennie_16.jpg
# Image saved as turochamp_glennie_17.jpg
# Image saved as turochamp_glennie_18.jpg
# Image saved as turochamp_glennie_19.jpg
# Image saved as turochamp_glennie_20.jpg
# Image saved as turochamp_glennie_21.jpg
# Image saved as turochamp_glennie_22.jpg
# ...
